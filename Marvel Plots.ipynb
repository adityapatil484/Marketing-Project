# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib

# %%
df = pd.read_csv(r"C:/Users/adity/Downloads/Marketing Project/Marvel_Dataset.csv")

# %%
df
# Out:
#      Unnamed: 0  H.Posters  H.Trailers  H.Friends / Family  H.Comic books  \
# 0             0          1           1                   1              1
# 1             1          0           1                   0              0
# 2             2          1           1                   1              0
# 3             3          0           0                   1              0
# 4             4          0           1                   1              1
# ..          ...        ...         ...                 ...            ...
# 188         188          0           0                   1              0
# 189         189          1           1                   1              1
# 190         190          0           1                   0              0
# 191         191          0           0                   1              0
# 192         192          0           0                   1              0
#
#      H.Twitter posts  H.Instagram posts  H.Facebook pages  H.Newspaper  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'H.Posters', 'H.Trailers', 'H.Friends / Family',
#        'H.Comic books', 'H.Twitter posts', 'H.Instagram posts',
#        'H.Facebook pages', 'H.Newspaper', 'H.Games', 'G.Cast', 'G.Plot',
#        'G.Trailer', 'G.Liked previous movies from this franchise',
#        'G.Social media presense', 'G.Director', 'G.Poster', 'A.Characters',
#        'A.Story', 'A.Director', 'A.Action', 'A.Cast',
#        'A.Visuals/Special effects', 'A.Realism', 'A.Cinematography',
#        'A.Themes of the movie', 'A.Humor', 'A.Message of the movie',
#        'P.Comics', 'P.Merchandise', 'P.Action figures', 'P.Games',
#        'P.Special edition DVDs/Blurays', 'Preference', 'Age_range', 'Gender'],
#       dtype='object')

# %%
df[['H.Posters', 'H.Trailers', 'H.Friends / Family',
       'H.Comic books', 'H.Twitter posts', 'H.Instagram posts',
       'H.Facebook pages', 'H.Newspaper', 'H.Games']].sum()
# Out:
# H.Posters              64
# H.Trailers            145
# H.Friends / Family    133
# H.Comic books          40
# H.Twitter posts        20
# H.Instagram posts      74
# H.Facebook pages       32
# H.Newspaper            31
# H.Games                16
# dtype: int64

# %%
df[['G.Cast', 'G.Plot',
       'G.Trailer', 'G.Liked previous movies from this franchise',
       'G.Social media presense', 'G.Director', 'G.Poster']].sum()
# Out:
# G.Cast                                         102
# G.Plot                                          77
# G.Trailer                                      100
# G.Liked previous movies from this franchise    119
# G.Social media presense                         54
# G.Director                                      38
# G.Poster                                        36
# dtype: int64

# %%
df[['A.Characters',
       'A.Story', 'A.Director', 'A.Action', 'A.Cast',
       'A.Visuals/Special effects', 'A.Realism', 'A.Cinematography',
       'A.Themes of the movie', 'A.Humor', 'A.Message of the movie']].sum()
# Out:
# A.Characters                 147
# A.Story                       95
# A.Director                    28
# A.Action                     120
# A.Cast                        69
# A.Visuals/Special effects    130
# A.Realism                     16
# A.Cinematography              79
# A.Themes of the movie         50
# A.Humor                       65
# A.Message of the movie        28
# dtype: int64

# %%
df[['P.Comics', 'P.Merchandise', 'P.Action figures', 'P.Games',
       'P.Special edition DVDs/Blurays']].sum()
# Out:
# P.Comics                          36
# P.Merchandise                     96
# P.Action figures                  33
# P.Games                           32
# P.Special edition DVDs/Blurays    13
# dtype: int64

# %%
N = 9

blue_bar = df[['H.Posters', 'H.Trailers', 'H.Friends / Family',
       'H.Comic books', 'H.Twitter posts', 'H.Instagram posts',
       'H.Facebook pages', 'H.Newspaper', 'H.Games']][df.Gender=="Male"].sum()

orange_bar = df[['H.Posters', 'H.Trailers', 'H.Friends / Family',
       'H.Comic books', 'H.Twitter posts', 'H.Instagram posts',
       'H.Facebook pages', 'H.Newspaper', 'H.Games']][df.Gender=="Female"].sum()

ind = np.arange(N)

plt.figure(figsize=(20,10))

width = 0.3      

plt.bar(ind, blue_bar , width, label='Male')
plt.bar(ind + width, orange_bar, width, label='Female')

plt.ylabel('count')
plt.xlabel('Where did you first hear about this movie?')

plt.xticks(ind + width / 2, (('Posters','Trailers','Friends/Family','Comic Books', 'Twitter Posts','Instagram Posts','Facebook Pages','Newspapers','Games')))

plt.legend(loc='best')
plt.show()

# %%
N = 7

blue_bar = df[['G.Cast', 'G.Plot',
       'G.Trailer', 'G.Liked previous movies from this franchise',
       'G.Social media presense', 'G.Director', 'G.Poster']][df.Gender=="Male"].sum()

orange_bar = df[['G.Cast', 'G.Plot',
       'G.Trailer', 'G.Liked previous movies from this franchise',
       'G.Social media presense', 'G.Director', 'G.Poster']][df.Gender=="Female"].sum()

ind = np.arange(N)

plt.figure(figsize=(20,10))

width = 0.3      

plt.bar(ind, blue_bar , width, label='Male')
plt.bar(ind + width, orange_bar, width, label='Female')

plt.ylabel('count')
plt.xlabel('What made you go to this movie?')

plt.xticks(ind + width / 2, (('Cast','Plot','Trailer','Liked the prev movie in franchise','Social Media Presence','Director','Poster')))

plt.legend(loc='best')
plt.show()

# %%
N = 11

blue_bar = df[['A.Characters',
       'A.Story', 'A.Director', 'A.Action', 'A.Cast',
       'A.Visuals/Special effects', 'A.Realism', 'A.Cinematography',
       'A.Themes of the movie', 'A.Humor', 'A.Message of the movie']][df.Gender=="Male"].sum()

orange_bar = df[['A.Characters',
       'A.Story', 'A.Director', 'A.Action', 'A.Cast',
       'A.Visuals/Special effects', 'A.Realism', 'A.Cinematography',
       'A.Themes of the movie', 'A.Humor', 'A.Message of the movie']][df.Gender=="Female"].sum()

ind = np.arange(N)

plt.figure(figsize=(20,10))

width = 0.3      

plt.bar(ind, blue_bar , width, label='Male')
plt.bar(ind + width, orange_bar, width, label='Female')

plt.ylabel('count')
plt.xlabel('After watching this movie, what are the things that appealed to you?')

plt.xticks(ind + width / 2, (('Characters','Story','Director','Action','Cast','Visuals','Realism','Cinematography','Themes','Humor','Message')))

plt.legend(loc='best')
plt.show()

# %%
N = 5

blue_bar = df[['P.Comics', 'P.Merchandise', 'P.Action figures', 'P.Games',
       'P.Special edition DVDs/Blurays']][df.Gender=="Male"].sum()

orange_bar = df[['P.Comics', 'P.Merchandise', 'P.Action figures', 'P.Games',
       'P.Special edition DVDs/Blurays']][df.Gender=="Female"].sum()

ind = np.arange(N)

plt.figure(figsize=(20,10))

width = 0.3      

plt.bar(ind, blue_bar , width, label='Male')
plt.bar(ind + width, orange_bar, width, label='Female')

plt.ylabel('count')
plt.xlabel('Have you bought any products associated with Marvel?')

plt.xticks(ind + width / 2, (('Comics','Merchandise','Action figures','Games','Special edition DVD/Blu-ray')))

plt.legend(loc='best')
plt.show()

# %%
N = 9

blue_bar = df[['H.Posters', 'H.Trailers', 'H.Friends / Family',
       'H.Comic books', 'H.Twitter posts', 'H.Instagram posts',
       'H.Facebook pages', 'H.Newspaper', 'H.Games']][df.Age_range=="10-17"].sum()

orange_bar = df[['H.Posters', 'H.Trailers', 'H.Friends / Family',
       'H.Comic books', 'H.Twitter posts', 'H.Instagram posts',
       'H.Facebook pages', 'H.Newspaper', 'H.Games']][df.Age_range=="18-25"].sum()


red_bar = df[['H.Posters', 'H.Trailers', 'H.Friends / Family',
       'H.Comic books', 'H.Twitter posts', 'H.Instagram posts',
       'H.Facebook pages', 'H.Newspaper', 'H.Games']][df.Age_range=="26-40"].sum()

yellow_bar =  df[['H.Posters', 'H.Trailers', 'H.Friends / Family',
       'H.Comic books', 'H.Twitter posts', 'H.Instagram posts',
       'H.Facebook pages', 'H.Newspaper', 'H.Games']][df.Age_range=="41-55"].sum()

green_bar = df[['H.Posters', 'H.Trailers', 'H.Friends / Family',
       'H.Comic books', 'H.Twitter posts', 'H.Instagram posts',
       'H.Facebook pages', 'H.Newspaper', 'H.Games']][df.Age_range=="55+"].sum()

ind = np.arange(N)

plt.figure(figsize=(20,10))

width = 0.3      

plt.bar(ind, blue_bar , width, label='10-17')
plt.bar(ind + width, orange_bar, width, label='18-25')
plt.bar(ind + width, red_bar, width, label='26-40')
plt.bar(ind + width, yellow_bar, width, label='41-55')
plt.bar(ind + width, green_bar, width, label='55+')


plt.ylabel('count')
plt.xlabel('Where did you first hear about this movie?')

plt.xticks(ind + width / 2, (('Posters','Trailers','Friends/Family','Comic Books', 'Twitter Posts','Instagram Posts','Facebook Pages','Newspapers','Games')))

plt.legend(loc='best')
plt.show()

# %%
N = 7

blue_bar = df[['G.Cast', 'G.Plot',
       'G.Trailer', 'G.Liked previous movies from this franchise',
       'G.Social media presense', 'G.Director', 'G.Poster']][df.Age_range=="10-17"].sum()

orange_bar = df[['G.Cast', 'G.Plot',
       'G.Trailer', 'G.Liked previous movies from this franchise',
       'G.Social media presense', 'G.Director', 'G.Poster']][df.Age_range=="18-25"].sum()


red_bar = df[['G.Cast', 'G.Plot',
       'G.Trailer', 'G.Liked previous movies from this franchise',
       'G.Social media presense', 'G.Director', 'G.Poster']][df.Age_range=="26-40"].sum()

yellow_bar =  df[['G.Cast', 'G.Plot',
       'G.Trailer', 'G.Liked previous movies from this franchise',
       'G.Social media presense', 'G.Director', 'G.Poster']][df.Age_range=="41-55"].sum()

green_bar = df[['G.Cast', 'G.Plot',
       'G.Trailer', 'G.Liked previous movies from this franchise',
       'G.Social media presense', 'G.Director', 'G.Poster']][df.Age_range=="55+"].sum()

ind = np.arange(N)

plt.figure(figsize=(20,10))

width = 0.3      

plt.bar(ind, blue_bar , width, label='10-17')
plt.bar(ind + width, orange_bar, width, label='18-25')
plt.bar(ind + width, red_bar, width, label='26-40')
plt.bar(ind + width, yellow_bar, width, label='41-55')
plt.bar(ind + width, green_bar, width, label='55+')

plt.ylabel('count')
plt.xlabel('What made you go to this movie?')

plt.xticks(ind + width / 2, (('Cast','Plot','Trailer','Liked the prev movie in franchise','Social Media Presence','Director','Poster')))

plt.legend(loc='best')
plt.show()

# %%
N = 11

blue_bar = df[['A.Characters',
       'A.Story', 'A.Director', 'A.Action', 'A.Cast',
       'A.Visuals/Special effects', 'A.Realism', 'A.Cinematography',
       'A.Themes of the movie', 'A.Humor', 'A.Message of the movie']][df.Age_range=="10-17"].sum()

orange_bar = df[['A.Characters',
       'A.Story', 'A.Director', 'A.Action', 'A.Cast',
       'A.Visuals/Special effects', 'A.Realism', 'A.Cinematography',
       'A.Themes of the movie', 'A.Humor', 'A.Message of the movie']][df.Age_range=="18-25"].sum()


red_bar = df[['A.Characters',
       'A.Story', 'A.Director', 'A.Action', 'A.Cast',
       'A.Visuals/Special effects', 'A.Realism', 'A.Cinematography',
       'A.Themes of the movie', 'A.Humor', 'A.Message of the movie']][df.Age_range=="26-40"].sum()

yellow_bar =  df[['A.Characters',
       'A.Story', 'A.Director', 'A.Action', 'A.Cast',
       'A.Visuals/Special effects', 'A.Realism', 'A.Cinematography',
       'A.Themes of the movie', 'A.Humor', 'A.Message of the movie']][df.Age_range=="41-55"].sum()

green_bar = df[['A.Characters',
       'A.Story', 'A.Director', 'A.Action', 'A.Cast',
       'A.Visuals/Special effects', 'A.Realism', 'A.Cinematography',
       'A.Themes of the movie', 'A.Humor', 'A.Message of the movie']][df.Age_range=="55+"].sum()

ind = np.arange(N)

plt.figure(figsize=(20,10))

width = 0.3      

plt.bar(ind, blue_bar , width, label='10-17')
plt.bar(ind + width, orange_bar, width, label='18-25')
plt.bar(ind + width, red_bar, width, label='26-40')
plt.bar(ind + width, yellow_bar, width, label='41-55')
plt.bar(ind + width, green_bar, width, label='55+')

plt.ylabel('count')
plt.xlabel('After watching this movie, what are the things that appealed to you?')

plt.xticks(ind + width / 2, (('Characters','Story','Director','Action','Cast','Visuals','Realism','Cinematography','Themes','Humor','Message')))

plt.legend(loc='best')
plt.show()

# %%
N = 5

blue_bar = df[['P.Comics', 'P.Merchandise', 'P.Action figures', 'P.Games',
       'P.Special edition DVDs/Blurays']][df.Age_range=="10-17"].sum()

orange_bar = df[['P.Comics', 'P.Merchandise', 'P.Action figures', 'P.Games',
       'P.Special edition DVDs/Blurays']][df.Age_range=="18-25"].sum()


red_bar = df[['P.Comics', 'P.Merchandise', 'P.Action figures', 'P.Games',
       'P.Special edition DVDs/Blurays']][df.Age_range=="26-40"].sum()

yellow_bar =  df[['P.Comics', 'P.Merchandise', 'P.Action figures', 'P.Games',
       'P.Special edition DVDs/Blurays']][df.Age_range=="41-55"].sum()

green_bar = df[['P.Comics', 'P.Merchandise', 'P.Action figures', 'P.Games',
       'P.Special edition DVDs/Blurays']][df.Age_range=="55+"].sum()

ind = np.arange(N)

plt.figure(figsize=(30,15))

width = 0.3      

plt.bar(ind, blue_bar , width, label='10-17')
plt.bar(ind + width, orange_bar, width, label='18-25')
plt.bar(ind + width, red_bar, width, label='26-40')
plt.bar(ind + width, yellow_bar, width, label='41-55')
plt.bar(ind + width, green_bar, width, label='55+')

plt.ylabel('count')
plt.xlabel('Have you bought any products associated with Marvel?')

plt.xticks(ind + width / 2, (('Comics','Merchandise','Action figures','Games','Special edition DVD/Blu-ray')))

matplotlib.rc('xtick', labelsize=10) 
matplotlib.rc('ytick', labelsize=10)

plt.legend(loc='best')
plt.show()

# %%
N = 9

blue_bar = df[['H.Posters', 'H.Trailers', 'H.Friends / Family',
       'H.Comic books', 'H.Twitter posts', 'H.Instagram posts',
       'H.Facebook pages', 'H.Newspaper', 'H.Games']][df.Preference== "Marvel"].sum()

orange_bar = df[['H.Posters', 'H.Trailers', 'H.Friends / Family',
       'H.Comic books', 'H.Twitter posts', 'H.Instagram posts',
       'H.Facebook pages', 'H.Newspaper', 'H.Games']][df.Preference== "DC"].sum()

ind = np.arange(N)

plt.figure(figsize=(20,10))

width = 0.3      

plt.bar(ind, blue_bar , width, label='Marvel')
plt.bar(ind + width, orange_bar, width, label='DC')

plt.ylabel('count')
plt.xlabel('Where did you first hear about this movie?')

plt.xticks(ind + width / 2, (('Posters','Trailers','Friends/Family','Comic Books', 'Twitter Posts','Instagram Posts','Facebook Pages','Newspapers','Games')))

plt.legend(loc='best')
plt.show()

# %%
N = 7

blue_bar = df[['G.Cast', 'G.Plot',
       'G.Trailer', 'G.Liked previous movies from this franchise',
       'G.Social media presense', 'G.Director', 'G.Poster']][df.Preference=="Marvel"].sum()

orange_bar = df[['G.Cast', 'G.Plot',
       'G.Trailer', 'G.Liked previous movies from this franchise',
       'G.Social media presense', 'G.Director', 'G.Poster']][df.Preference=="DC"].sum()

ind = np.arange(N)

plt.figure(figsize=(20,10))

width = 0.3      

plt.bar(ind, blue_bar , width, label='Marvel')
plt.bar(ind + width, orange_bar, width, label='DC')

plt.ylabel('count')
plt.xlabel('What made you go to this movie?')

plt.xticks(ind + width / 2, (('Cast','Plot','Trailer','Liked the prev movie in franchise','Social Media Presence','Director','Poster')))

plt.legend(loc='best')
plt.show()

# %%
N = 11

blue_bar = df[['A.Characters',
       'A.Story', 'A.Director', 'A.Action', 'A.Cast',
       'A.Visuals/Special effects', 'A.Realism', 'A.Cinematography',
       'A.Themes of the movie', 'A.Humor', 'A.Message of the movie']][df.Preference=="Marvel"].sum()

orange_bar = df[['A.Characters',
       'A.Story', 'A.Director', 'A.Action', 'A.Cast',
       'A.Visuals/Special effects', 'A.Realism', 'A.Cinematography',
       'A.Themes of the movie', 'A.Humor', 'A.Message of the movie']][df.Preference=="DC"].sum()

ind = np.arange(N)

plt.figure(figsize=(20,10))

width = 0.3      

plt.bar(ind, blue_bar , width, label='Marvel')
plt.bar(ind + width, orange_bar, width, label='DC')

plt.ylabel('count')
plt.xlabel('After watching this movie, what are the things that appealed to you?')

plt.xticks(ind + width / 2, (('Characters','Story','Director','Action','Cast','Visuals','Realism','Cinematography','Themes','Humor','Message')))

plt.legend(loc='best')
plt.show()

# %%
N = 5

blue_bar = df[['P.Comics', 'P.Merchandise', 'P.Action figures', 'P.Games',
       'P.Special edition DVDs/Blurays']][df.Preference=="Marvel"].sum()

orange_bar = df[['P.Comics', 'P.Merchandise', 'P.Action figures', 'P.Games',
       'P.Special edition DVDs/Blurays']][df.Preference=="DC"].sum()

ind = np.arange(N)

plt.figure(figsize=(20,10))

width = 0.3      

plt.bar(ind, blue_bar , width, label='Marvel')
plt.bar(ind + width, orange_bar, width, label='DC')

plt.ylabel('count')
plt.xlabel('Have you bought any products associated with Marvel?')

plt.xticks(ind + width / 2, (('Comics','Merchandise','Action figures','Games','Special edition DVD/Blu-ray')))

plt.legend(loc='best')
plt.show()

# %%
count = df['Age_range'].value_counts()

# %%
count
# Out:
# 18-25          111
# 10-17 years     33
# 26-40           24
# 41-55           23
# 55+              2
# Name: Age_range, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Female               97
# Male                 91
# Prefer not to say     5
# Name: Gender, dtype: int64

# %%
len(df[df["Gender"] == "Male"]) / len(df)
# Out:
# 0.47150259067357514

# %%
len(df[df["Gender"] == "Female"]) / len(df)
# Out:
# 0.5025906735751295

# %%
len(df)
# Out:
# 193

# %%
len(df[df["Gender"]=="Female"])
# Out:
# 97

# %%
len(df[df["Gender"]=="Male"])
# Out:
# 91
